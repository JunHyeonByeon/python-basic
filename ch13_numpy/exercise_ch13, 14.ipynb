# %% [markdown]
# # 13장 연습문제 Numpy 데이터 분석

# %%
import pandas as pd
import numpy as np
# Matplotlib 사용과 한글 처리를 위한 Code
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False   # minus 표시
mpl.rc('font', family='Malgun Gothic')
# %matplotlib inline
plt.rcParams["figure.figsize"] = (12,6)
plt.rcParams["font.size"] = 14

# %%
# 3.
hs = pd.read_csv('high_school_2019.csv')

df = hs.iloc[:, 2:]
df
# Out:
#        1학년 학급수   1학년 학생수   2학년 학급수   2학년 학생수   3학년 학급수   3학년 학생수
# 0            5       150         5       149         5       143
# 1            8       239         8       228         8       270
# 2            6       182         6       174         6       169
# 3           11       282        11       262        11       288
# 4            8       210         8       183         8       221
# ...        ...       ...       ...       ...       ...       ...
# 2393        11       279        11       279        11       305
# 2394         8       151         8       141         8       135
# 2395         4        76         5        91         5       103
# 2396         4        99         4        95         4        92
# 2397         5       116         5        98         5       126
#
# [2398 rows x 6 columns]

# %%
df2 = df.iloc[:,1::2]
df2
# Out:
#        1학년 학생수   2학년 학생수   3학년 학생수
# 0          150       149       143
# 1          239       228       270
# 2          182       174       169
# 3          282       262       288
# 4          210       183       221
# ...        ...       ...       ...
# 2393       279       279       305
# 2394       151       141       135
# 2395        76        91       103
# 2396        99        95        92
# 2397       116        98       126
#
# [2398 rows x 3 columns]

# %%
df['총 학생수'] = df2.sum(axis=1)
df
# Out:
#        1학년 학급수   1학년 학생수   2학년 학급수   2학년 학생수   3학년 학급수   3학년 학생수  총 학생수
# 0            5       150         5       149         5       143    442
# 1            8       239         8       228         8       270    737
# 2            6       182         6       174         6       169    525
# 3           11       282        11       262        11       288    832
# 4            8       210         8       183         8       221    614
# ...        ...       ...       ...       ...       ...       ...    ...
# 2393        11       279        11       279        11       305    863
# 2394         8       151         8       141         8       135    427
# 2395         4        76         5        91         5       103    270
# 2396         4        99         4        95         4        92    286
# 2397         5       116         5        98         5       126    340
#
# [2398 rows x 7 columns]

# %%
# 4.
df2 = df.iloc[:,1::2]
df2
# Out:
#        1학년 학생수   2학년 학생수   3학년 학생수
# 0          150       149       143
# 1          239       228       270
# 2          182       174       169
# 3          282       262       288
# 4          210       183       221
# ...        ...       ...       ...
# 2393       279       279       305
# 2394       151       141       135
# 2395        76        91       103
# 2396        99        95        92
# 2397       116        98       126
#
# [2398 rows x 3 columns]

# %%
df2.columns = ['1학년', '2학년', '3학년']
df2
# Out:
#       1학년  2학년  3학년
# 0     150  149  143
# 1     239  228  270
# 2     182  174  169
# 3     282  262  288
# 4     210  183  221
# ...   ...  ...  ...
# 2393  279  279  305
# 2394  151  141  135
# 2395   76   91  103
# 2396   99   95   92
# 2397  116   98  126
#
# [2398 rows x 3 columns]

# %%
df3 = df2[['1학년', '2학년', '3학년']].sum()
df3
# Out:
# 1학년    463400
# 2학년    444714
# 3학년    500698
# dtype: int64

# %%
df3.plot.bar()
plt.title('전국 고등학교 학년별 총 학생수')
plt.show()

# %% [markdown]
# # 14장 연습문제 Pandas 데이터 분석

# %%
# 5.
df = pd.read_csv('population_age_2020.csv')
df
# Out:
#       지역      총인구수     0~9세   10~19세   20~29세   30~39세   40~49세   50~59세  \
# 0     서울   9736962   658355   813563  1455903  1505729  1563968  1539385
# 1     부산   3410925   241624   281120   434692   431911   518321   580966
# 2     대구   2432883   186623   234528   321487   303397   391997   428622
# 3     인천   2954955   239941   281097   405835   417708   490716   515758
# 4     광주   1456121   125396   162728   207554   191432   244903   234048
# 5     대전   1473125   120476   151861   212143   199106   242381   243526
# 6     울산   1145710   103399   115623   147745   158271   190698   211255
# 7     세종    343788    47454    40574    36273    61442    65714    42907
# 8    경기도  13265377  1178548  1347854  1769080  1917785  2299179  2205106
# 9    강원도   1539521   108694   141975   179813   169694   227950   269666
# 10  충청북도   1598599   128290   153119   198910   198768   243982   273857
# 11  충청남도   2120995   179808   206578   243748   276553   329789   340568
# ...

# %%
df = df.loc[:, ['지역', '100세 이상', '총인구수']]

# %%
df = df.sort_values(by='100세 이상', ascending=False).reset_index(drop=True)

# %%
df
# Out:
#       지역  100세 이상      총인구수
# 0     서울     6380   9736962
# 1    경기도     4010  13265377
# 2     부산     1807   3410925
# 3   경상북도      960   2658956
# 4     인천      908   2954955
# 5   충청남도      885   2120995
# 6   전라남도      822   1861894
# 7   전라북도      817   1815112
# 8    강원도      803   1539521
# 9   경상남도      739   3358828
# 10    대구      694   2432883
# 11  충청북도      541   1598599
# 12    광주      405   1456121
# 13    대전      339   1473125
# 14   제주도      266    670876
# 15    울산      160   1145710
# 16    세종       55    343788
